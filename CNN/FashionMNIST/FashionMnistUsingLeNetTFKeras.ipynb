# %%
import tensorflow
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
class myCallback1(tensorflow.keras.callbacks.Callback):
            def on_epoch_end(self, epoch, logs={}):
                if(logs.get('accuracy')>0.9950):
                    print("\nReached 99.50% accuracy so cancelling training!")
                    self.model.stop_training = True
callbacks=myCallback1()

# %%
fashion_mnist = tensorflow.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train=x_train.reshape(60000, 28, 28, 1)
x_train=x_train / 255.0
x_test= x_test.reshape(10000, 28, 28, 1)
x_test=x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1) (60000,) (10000,)

# %%
EPOCHS=100
LEARNING_RATE=0.001

# %%
#we are using sparse_categorical_crossentropy hence no need to convert to one-hot vector
#y_train = tensorflow.keras.utils.to_categorical(y_train, CLASSES)
#y_test = tensorflow.keras.utils.to_categorical(y_test, CLASSES)

# %%
model=tensorflow.keras.Sequential([
      layers.Conv2D(filters=6, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)),
      layers.AveragePooling2D(),
      layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu'),
      layers.AveragePooling2D(),
      layers.Flatten(),
      layers.Dense(units=120, activation='relu'),
      layers.Dense(units=84, activation='relu'),
      #layers.Dropout(0.2),
      layers.Dense(units=10, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 6)         60
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 13, 13, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 16)        880
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 60,074
# Trainable params: 60,074
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tensorflow.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history=model.fit(
        x_train,y_train,
        epochs=EPOCHS,
        validation_data=(x_test,y_test),
        callbacks=[callbacks]
)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5611 - accuracy: 0.7907 - val_loss: 0.4415 - val_accuracy: 0.8375
# Epoch 2/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3828 - accuracy: 0.8597 - val_loss: 0.3924 - val_accuracy: 0.8508
# Epoch 3/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3330 - accuracy: 0.8775 - val_loss: 0.3468 - val_accuracy: 0.8726
# Epoch 4/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3027 - accuracy: 0.8874 - val_loss: 0.3211 - val_accuracy: 0.8813
# Epoch 5/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2826 - accuracy: 0.8946 - val_loss: 0.3065 - val_accuracy: 0.8899
# Epoch 6/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2664 - accuracy: 0.9002 - val_loss: 0.3103 - val_accuracy: 0.8882
# Epoch 7/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2516 - accuracy: 0.9059 - val_loss: 0.2998 - val_accuracy: 0.8905
# Epoch 8/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2409 - accuracy: 0.9099 - val_loss: 0.2934 - val_accuracy: 0.8939
# Epoch 9/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2294 - accuracy: 0.9142 - val_loss: 0.2762 - val_accuracy: 0.9011
# Epoch 10/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2191 - accuracy: 0.9171 - val_loss: 0.2842 - val_accuracy: 0.8978
# Epoch 11/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2095 - accuracy: 0.9209 - val_loss: 0.2663 - val_accuracy: 0.9065
# Epoch 12/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2014 - accuracy: 0.9228 - val_loss: 0.2752 - val_accuracy: 0.9035
# Epoch 13/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1943 - accuracy: 0.9267 - val_loss: 0.2572 - val_accuracy: 0.9082
# Epoch 14/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1858 - accuracy: 0.9294 - val_loss: 0.2725 - val_accuracy: 0.9034
# Epoch 15/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1791 - accuracy: 0.9325 - val_loss: 0.2643 - val_accuracy: 0.9076
# Epoch 16/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1711 - accuracy: 0.9344 - val_loss: 0.2738 - val_accuracy: 0.9029
# Epoch 17/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1660 - accuracy: 0.9369 - val_loss: 0.2770 - val_accuracy: 0.9067
# Epoch 18/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1574 - accuracy: 0.9399 - val_loss: 0.2628 - val_accuracy: 0.9123
# Epoch 19/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1517 - accuracy: 0.9426 - val_loss: 0.2892 - val_accuracy: 0.9076
# Epoch 20/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1475 - accuracy: 0.9430 - val_loss: 0.2868 - val_accuracy: 0.9069
# Epoch 21/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1420 - accuracy: 0.9451 - val_loss: 0.2905 - val_accuracy: 0.9053
# Epoch 22/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1359 - accuracy: 0.9472 - val_loss: 0.2971 - val_accuracy: 0.9114
# Epoch 23/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1313 - accuracy: 0.9500 - val_loss: 0.2982 - val_accuracy: 0.9085
# Epoch 24/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1272 - accuracy: 0.9504 - val_loss: 0.3187 - val_accuracy: 0.9033
# Epoch 25/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1234 - accuracy: 0.9521 - val_loss: 0.3072 - val_accuracy: 0.9094
# Epoch 26/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1171 - accuracy: 0.9550 - val_loss: 0.3358 - val_accuracy: 0.9035
# Epoch 27/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1129 - accuracy: 0.9568 - val_loss: 0.3376 - val_accuracy: 0.9046
# Epoch 28/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1071 - accuracy: 0.9595 - val_loss: 0.3509 - val_accuracy: 0.9048
# Epoch 29/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1052 - accuracy: 0.9593 - val_loss: 0.3360 - val_accuracy: 0.9031
# Epoch 30/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1013 - accuracy: 0.9599 - val_loss: 0.3526 - val_accuracy: 0.9055
# Epoch 31/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0973 - accuracy: 0.9626 - val_loss: 0.3593 - val_accuracy: 0.9094
# Epoch 32/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0935 - accuracy: 0.9640 - val_loss: 0.3698 - val_accuracy: 0.9056
# Epoch 33/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0888 - accuracy: 0.9649 - val_loss: 0.3740 - val_accuracy: 0.9067
# Epoch 34/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0856 - accuracy: 0.9667 - val_loss: 0.3923 - val_accuracy: 0.9025
# Epoch 35/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0842 - accuracy: 0.9678 - val_loss: 0.3986 - val_accuracy: 0.9037
# Epoch 36/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0823 - accuracy: 0.9683 - val_loss: 0.4130 - val_accuracy: 0.9035
# Epoch 37/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0797 - accuracy: 0.9697 - val_loss: 0.4246 - val_accuracy: 0.9041
# Epoch 38/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0767 - accuracy: 0.9701 - val_loss: 0.4494 - val_accuracy: 0.9005
# Epoch 39/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0723 - accuracy: 0.9727 - val_loss: 0.4406 - val_accuracy: 0.9046
# Epoch 40/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0689 - accuracy: 0.9736 - val_loss: 0.4407 - val_accuracy: 0.9017
# Epoch 41/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0677 - accuracy: 0.9735 - val_loss: 0.4786 - val_accuracy: 0.8993
# Epoch 42/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0669 - accuracy: 0.9736 - val_loss: 0.4448 - val_accuracy: 0.9055
# Epoch 43/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0621 - accuracy: 0.9768 - val_loss: 0.4808 - val_accuracy: 0.8965
# Epoch 44/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0634 - accuracy: 0.9755 - val_loss: 0.5095 - val_accuracy: 0.9036
# Epoch 45/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0595 - accuracy: 0.9774 - val_loss: 0.5149 - val_accuracy: 0.8999
# Epoch 46/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0573 - accuracy: 0.9782 - val_loss: 0.5037 - val_accuracy: 0.9046
# Epoch 47/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0567 - accuracy: 0.9786 - val_loss: 0.5222 - val_accuracy: 0.9030
# Epoch 48/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0553 - accuracy: 0.9792 - val_loss: 0.5276 - val_accuracy: 0.9057
# Epoch 49/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0547 - accuracy: 0.9792 - val_loss: 0.5145 - val_accuracy: 0.9004
# Epoch 50/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0539 - accuracy: 0.9801 - val_loss: 0.5559 - val_accuracy: 0.9057
# Epoch 51/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0504 - accuracy: 0.9811 - val_loss: 0.5635 - val_accuracy: 0.9034
# Epoch 52/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0499 - accuracy: 0.9819 - val_loss: 0.5700 - val_accuracy: 0.9030
# Epoch 53/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0475 - accuracy: 0.9821 - val_loss: 0.6102 - val_accuracy: 0.8975
# Epoch 54/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0484 - accuracy: 0.9820 - val_loss: 0.6068 - val_accuracy: 0.9013
# Epoch 55/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0481 - accuracy: 0.9822 - val_loss: 0.5876 - val_accuracy: 0.8941
# Epoch 56/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0451 - accuracy: 0.9835 - val_loss: 0.5869 - val_accuracy: 0.9032
# Epoch 57/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0418 - accuracy: 0.9844 - val_loss: 0.6132 - val_accuracy: 0.9049
# Epoch 58/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0443 - accuracy: 0.9832 - val_loss: 0.6379 - val_accuracy: 0.9061
# Epoch 59/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0405 - accuracy: 0.9848 - val_loss: 0.6379 - val_accuracy: 0.9017
# Epoch 60/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0417 - accuracy: 0.9842 - val_loss: 0.6541 - val_accuracy: 0.9019
# Epoch 61/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0381 - accuracy: 0.9857 - val_loss: 0.6654 - val_accuracy: 0.8980
# Epoch 62/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0412 - accuracy: 0.9852 - val_loss: 0.6754 - val_accuracy: 0.9032
# Epoch 63/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0366 - accuracy: 0.9866 - val_loss: 0.6887 - val_accuracy: 0.8991
# Epoch 64/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0386 - accuracy: 0.9858 - val_loss: 0.6869 - val_accuracy: 0.9006
# Epoch 65/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0389 - accuracy: 0.9861 - val_loss: 0.6975 - val_accuracy: 0.9007
# Epoch 66/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0361 - accuracy: 0.9864 - val_loss: 0.6747 - val_accuracy: 0.8999
# Epoch 67/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0338 - accuracy: 0.9875 - val_loss: 0.6964 - val_accuracy: 0.9030
# Epoch 68/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0353 - accuracy: 0.9872 - val_loss: 0.7432 - val_accuracy: 0.9059
# Epoch 69/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0374 - accuracy: 0.9864 - val_loss: 0.7154 - val_accuracy: 0.9042
# Epoch 70/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0317 - accuracy: 0.9880 - val_loss: 0.7429 - val_accuracy: 0.9042
# Epoch 71/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0344 - accuracy: 0.9873 - val_loss: 0.7471 - val_accuracy: 0.9047
# Epoch 72/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0325 - accuracy: 0.9878 - val_loss: 0.7478 - val_accuracy: 0.9005
# Epoch 73/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0329 - accuracy: 0.9884 - val_loss: 0.8014 - val_accuracy: 0.9001
# Epoch 74/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0314 - accuracy: 0.9888 - val_loss: 0.7492 - val_accuracy: 0.9010
# Epoch 75/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0316 - accuracy: 0.9884 - val_loss: 0.7555 - val_accuracy: 0.9011
# Epoch 76/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.8293 - val_accuracy: 0.9037
# Epoch 77/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0301 - accuracy: 0.9890 - val_loss: 0.7940 - val_accuracy: 0.8997
# Epoch 78/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0330 - accuracy: 0.9886 - val_loss: 0.8381 - val_accuracy: 0.9003
# Epoch 79/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0314 - accuracy: 0.9888 - val_loss: 0.7770 - val_accuracy: 0.9019
# Epoch 80/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0298 - accuracy: 0.9894 - val_loss: 0.8154 - val_accuracy: 0.9008
# Epoch 81/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0315 - accuracy: 0.9893 - val_loss: 0.8007 - val_accuracy: 0.9029
# Epoch 82/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0237 - accuracy: 0.9918 - val_loss: 0.9079 - val_accuracy: 0.9026
# Epoch 83/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0307 - accuracy: 0.9894 - val_loss: 0.8542 - val_accuracy: 0.8992
# Epoch 84/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0304 - accuracy: 0.9896 - val_loss: 0.8473 - val_accuracy: 0.9012
# Epoch 85/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0274 - accuracy: 0.9901 - val_loss: 0.8913 - val_accuracy: 0.9007
# Epoch 86/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0280 - accuracy: 0.9903 - val_loss: 0.8376 - val_accuracy: 0.9034
# Epoch 87/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0308 - accuracy: 0.9897 - val_loss: 0.8723 - val_accuracy: 0.8991
# Epoch 88/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0243 - accuracy: 0.9916 - val_loss: 0.8294 - val_accuracy: 0.9009
# Epoch 89/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0324 - accuracy: 0.9891 - val_loss: 0.8253 - val_accuracy: 0.9009
# Epoch 90/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0261 - accuracy: 0.9911 - val_loss: 0.9046 - val_accuracy: 0.8966
# Epoch 91/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0284 - accuracy: 0.9904 - val_loss: 0.9024 - val_accuracy: 0.9017
# Epoch 92/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0290 - accuracy: 0.9903 - val_loss: 0.8577 - val_accuracy: 0.9033
# Epoch 93/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.9046 - val_accuracy: 0.9010
# Epoch 94/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0253 - accuracy: 0.9911 - val_loss: 0.8980 - val_accuracy: 0.9012
# Epoch 95/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0267 - accuracy: 0.9907 - val_loss: 0.9347 - val_accuracy: 0.9015
# Epoch 96/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0243 - accuracy: 0.9914 - val_loss: 0.9536 - val_accuracy: 0.9005
# Epoch 97/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0259 - accuracy: 0.9910 - val_loss: 0.9350 - val_accuracy: 0.9008
# Epoch 98/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0249 - accuracy: 0.9911 - val_loss: 1.0020 - val_accuracy: 0.9002
# Epoch 99/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0227 - accuracy: 0.9917 - val_loss: 1.0285 - val_accuracy: 0.8982
# Epoch 100/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0243 - accuracy: 0.9916 - val_loss: 1.0503 - val_accuracy: 0.8970

# %%
epochs=len(history.history['loss'])
plt.plot([i for i in range(1,epochs+1)],history.history['loss'],label="Train_loss")
plt.plot([i for i in range(1,epochs+1)],history.history['val_loss'],label="Validation_loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot([i for i in range(1,epochs+1)],history.history['accuracy'],label="Train_Accuracy")
plt.plot([i for i in range(1,epochs+1)],history.history['val_accuracy'],label="Validation_Accuracy")
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
